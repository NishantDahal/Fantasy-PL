# %%
# !git clone https://github.com/vaastav/Fantasy-Premier-League.git
# Out:
# Cloning into 'Fantasy-Premier-League'...
# Updating files:  25% (2789/11114)
# Updating files:  26% (2890/11114)
# Updating files:  27% (3001/11114)
# Updating files:  28% (3112/11114)
# Updating files:  29% (3224/11114)
# Updating files:  30% (3335/11114)
# Updating files:  31% (3446/11114)
# Updating files:  32% (3557/11114)
# Updating files:  33% (3668/11114)
# Updating files:  34% (3779/11114)
# Updating files:  35% (3890/11114)
# Updating files:  36% (4002/11114)
# Updating files:  37% (4113/11114)
# Updating files:  38% (4224/11114)
# Updating files:  39% (4335/11114)
# Updating files:  40% (4446/11114)
# Updating files:  41% (4557/11114)
# Updating files:  42% (4668/11114)
# Updating files:  43% (4780/11114)
# Updating files:  44% (4891/11114)
# Updating files:  45% (5002/11114)
# Updating files:  46% (5113/11114)
# Updating files:  47% (5224/11114)
# Updating files:  48% (5335/11114)
# Updating files:  49% (5446/11114)
# Updating files:  50% (5557/11114)
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Fantasy_PL\Fantasy-PL\Fantasy-Premier-League\data\cleaned_merged_seasons.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13924\1673143744.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('D:\Fantasy_PL\Fantasy-PL\Fantasy-Premier-League\data\cleaned_merged_seasons.csv')

# %%
# create a dataframe where only the values of the 2021-22 season are stored

df_2021 = df[df['season_x'] == '2021-22']

# %%
df_2021.head()
# Out:
#        Unnamed: 0 season_x                           name position  \
# 73837       73837  2021-22                    Eric Bailly      DEF
# 73838       73838  2021-22                   Keinan Davis      FWD
# 73839       73839  2021-22         Ayotomiwa Dele-Bashiru      MID
# 73840       73840  2021-22              James Ward-Prowse      MID
# 73841       73841  2021-22  Bruno Miguel Borges Fernandes      MID
#
#             team_x  assists  bonus  bps  clean_sheets  creativity  ...  \
# 73837      Man Utd        0      0    0             0         0.0  ...
# 73838  Aston Villa        0      0    0             0         0.0  ...
# 73839      Watford        0      0    0             0         0.0  ...
# 73840  Southampton        0      0   20             0        30.5  ...
# 73841      Man Utd        0      3   61             0        35.9  ...
#
#        team_h_score  threat  total_points  transfers_balance  transfers_in  \
# ...

# %%
# create a dataframe where the GW 1 values of the 2021-22 season are stored

df_2021_gw1 = df_2021[df_2021['GW'] == 1]

#display column names

df_2021_gw1.columns
# Out:
# Index(['Unnamed: 0', 'season_x', 'name', 'position', 'team_x', 'assists',
#        'bonus', 'bps', 'clean_sheets', 'creativity', 'element', 'fixture',
#        'goals_conceded', 'goals_scored', 'ict_index', 'influence',
#        'kickoff_time', 'minutes', 'opponent_team', 'opp_team_name',
#        'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards',
#        'round', 'saves', 'selected', 'team_a_score', 'team_h_score', 'threat',
#        'total_points', 'transfers_balance', 'transfers_in', 'transfers_out',
#        'value', 'was_home', 'yellow_cards', 'GW'],
#       dtype='object')

# %%
# Train_col
train_col = ['name', 'team_x', 'assists', 'bonus']
