# %%
# !git clone https://github.com/vaastav/Fantasy-Premier-League.git

# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\Fantasy_PL\\Fantasy-Premier-League\\data\\cleaned_merged_seasons.csv')
# Out:
# C:\Users\Nishant\AppData\Local\Temp\ipykernel_3692\2171938088.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('D:\\Fantasy_PL\\Fantasy-Premier-League\\data\\cleaned_merged_seasons.csv')

# %%
#display the entire row , if the name is Aaron Lebanon and is season is 2021-22

df.loc[(df['name'] == 'Marcus Rashford') & (df['season_x'] == '2021-22')]
# Out:
#        Unnamed: 0 season_x             name position   team_x  assists  bonus  \
# 73934       73934  2021-22  Marcus Rashford      MID  Man Utd        0      0
# 74490       74490  2021-22  Marcus Rashford      MID  Man Utd        0      0
# 75057       75057  2021-22  Marcus Rashford      MID  Man Utd        0      0
# 75638       75638  2021-22  Marcus Rashford      MID  Man Utd        0      0
# 76237       76237  2021-22  Marcus Rashford      MID  Man Utd        0      0
# 76843       76843  2021-22  Marcus Rashford      MID  Man Utd        0      0
# 77454       77454  2021-22  Marcus Rashford      MID  Man Utd        0      0
# 78067       78067  2021-22  Marcus Rashford      MID  Man Utd        0      0
# 78685       78685  2021-22  Marcus Rashford      MID  Man Utd        0      0
# 79303       79303  2021-22  Marcus Rashford      MID  Man Utd        0      0
# 79926       79926  2021-22  Marcus Rashford      MID  Man Utd        0      0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 season_x                name position team_x  assists  bonus  \
# 0           0  2016-17     Aaron Cresswell      DEF    NaN        0      0
# 1           1  2016-17        Aaron Lennon      MID    NaN        0      0
# 2           2  2016-17        Aaron Ramsey      MID    NaN        0      0
# 3           3  2016-17  Abdoulaye Doucouré      MID    NaN        0      0
# 4           4  2016-17        Adam Forshaw      MID    NaN        0      0
#
#    bps  clean_sheets  creativity  ...  team_h_score  threat  total_points  \
# 0    0             0         0.0  ...           2.0     0.0             0
# 1    6             0         0.3  ...           1.0     0.0             1
# 2    5             0         4.9  ...           3.0    23.0             2
# 3    0             0         0.0  ...           1.0     0.0             0
# 4    3             0         1.3  ...           1.0     0.0             1
#
#    transfers_balance  transfers_in  transfers_out value  was_home  \
# ...
